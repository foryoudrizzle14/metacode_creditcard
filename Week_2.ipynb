# %% [markdown]
# <a href="https://colab.research.google.com/github/foryoudrizzle14/metacode_creditcard/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
y_actual = [1, 1, 0, 0, 1, 0, 0, 0, 1, 1]
y_pred = [1, 0, 0, 1, 0, 0, 1, 1, 1, 0]

# %%
CM = confusion_matrix(y_actual, y_pred)
print('Confucius Matrix = \n', CM)
# Out:
# Confucius Matrix =
#  [[2 3]
#  [3 2]]

# %%
#visualization
import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.

    Parameters:
    cm (array-like): Confusion matrix data.
    classes (list): List of labels for the classes.
    normalize (bool): Whether to apply normalization.
    title (str): Title for the plot.
    cmap: Colormap to use for the plot.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.figure(figsize=(10, 7))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.

    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

# %%
import numpy as np

cnf_matrix = confusion_matrix(y_actual, y_pred,labels = [0,1])
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=[0,1], normalize=True, title='Normalized confusion matrix')
# Out:
# Normalized confusion matrix
# [[0.4 0.6]
#  [0.6 0.4]]

# %%
print('Accuracy = ', accuracy_score(y_actual, y_pred))
print('Report = \n', classification_report(y_actual, y_pred))
# Out:
# Accuracy =  0.4
# Report =
#                precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40         5
#            1       0.40      0.40      0.40         5
#
#     accuracy                           0.40        10
#    macro avg       0.40      0.40      0.40        10
# weighted avg       0.40      0.40      0.40        10

# %%
print ('Accuracy = ', accuracy_score(y_actual, y_pred))
print('Report = \n', classification_report(y_actual, y_pred))
# Out:
# Accuracy =  0.5
# Report =
#                precision    recall  f1-score   support
#
#          Cat       0.33      0.50      0.40         2
#          Dog       0.50      0.50      0.50         2
#        Horse       1.00      0.50      0.67         2
#
#     accuracy                           0.50         6
#    macro avg       0.61      0.50      0.52         6
# weighted avg       0.61      0.50      0.52         6

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
classes = ['Cat', 'Dog', 'Horse']

y_actual = ['Cat', 'Cat', 'Dog', 'Dog', 'Horse', 'Horse']
y_pred = ['Cat', 'Dog', 'Cat', 'Dog', 'Cat', 'Horse']

# %%
CM = confusion_matrix(y_actual, y_pred)
print('Confucius Matrix = \n', CM)
# Out:
# Confucius Matrix =
#  [[1 1 0]
#  [1 1 0]
#  [1 0 1]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from types import FrameType
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print("Normalized confusion matrix")
  else:
    print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in np.ndindex(cm.shape):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        plt.tight_layout()
        plt.show

# %%
import numpy as np

cnf_matrix = confusion_matrix(y_actual, y_pred, labels = ['Cat', 'Dog', 'Horse'])
np.set_printoptions(precision=2)

plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['Cat', 'Dog', 'Horse'], title='Normalized confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[1 1 0]
#  [1 1 0]
#  [1 0 1]]

# %%
print('Accuracy = ', accuracy_score(y_actual, y_pred))
print('Report = \n', classification_report(y_actual, y_pred))
# Out:
# Accuracy =  0.5
# Report =
#                precision    recall  f1-score   support
#
#          Cat       0.33      0.50      0.40         2
#          Dog       0.50      0.50      0.50         2
#        Horse       1.00      0.50      0.67         2
#
#     accuracy                           0.50         6
#    macro avg       0.61      0.50      0.52         6
# weighted avg       0.61      0.50      0.52         6

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print("TensorFlow Version: %s" % tf.__version__)
# Out:
# TensorFlow Version: 2.15.0

# %%
x_train = np.array([[1., 1.], [1., 2.], [2., 1.], [3., 2.], [3., 3.], [2., 3.]], dtype=np.float32)
y_train = np.array([[0.], [0.], [0.], [1.], [1.], [1.]], dtype=np.float32)

# %%
colors = ['red' if l == 0 else 'blue' for l in y_train]
plt.scatter(x_train[:, 0], x_train[:, 1], label='Logistic Regression', c=colors)

# %%
tf.random.set_seed(2020)
w= tf.Variable(tf.random.normal(shape=(2, 1), mean=0.0, stddev=1.0, dtype=tf.float32))
b = tf.Variable(tf.zeros(shape=(1, ), dtype=tf.float32))

print('# Weights: \n', w.numpy(), '\n\n Bias: \n', b.numpy())
# Out:
# # Weights:
#  [[-0.1 ]
#  [ 0.68]]
#
#  Bias:
#  [0.]

# %%
def hypothesis(x):
    z = tf.matmul(x, w) + b
    sigmoid = 1 / (1 + tf.exp(-z))
    return sigmoid

def cost_fn(H, Y):
    cost = -tf.reduce_mean(Y * tf.math.log(H) + (1 - Y) * tf.math.log(1 - H))
    return cost

learning_rate = 0.01
optimizer = tf.optimizers.SGD(learning_rate)

# %%
for step in range(5001):

    with tf.GradientTape() as g:
        pred = hypothesis(x_train)
        cost = cost_fn(pred, y_train)

    gradients = g.gradient(cost, [w, b])
    optimizer.apply_gradients(zip(gradients, [w, b]))

    if step % 200 == 0:
        print("step = %04d, cost = {}, W = {}, b = {}".format(step + 1, cost, w.numpy(), b.numpy()))

w_hat = w.numpy()
b_hat = b.numpy()
# Out:
# step = %04d, cost = 1, W = 0.2944369316101074, b = [[0.85]
#  [0.92]]
# step = %04d, cost = 201, W = 0.2848091423511505, b = [[0.89]
#  [0.95]]
# step = %04d, cost = 401, W = 0.2757890224456787, b = [[0.92]
#  [0.98]]
# step = %04d, cost = 601, W = 0.2673220932483673, b = [[0.96]
#  [1.  ]]
# step = %04d, cost = 801, W = 0.2593599855899811, b = [[0.99]
#  [1.03]]
# step = %04d, cost = 1001, W = 0.25185978412628174, b = [[1.02]
#  [1.06]]
# step = %04d, cost = 1201, W = 0.24478305876255035, b = [[1.05]
#  [1.08]]
# step = %04d, cost = 1401, W = 0.23809541761875153, b = [[1.08]
#  [1.1 ]]
# step = %04d, cost = 1601, W = 0.23176604509353638, b = [[1.1 ]
#  [1.13]]
# step = %04d, cost = 1801, W = 0.22576715052127838, b = [[1.13]
#  [1.15]]
# step = %04d, cost = 2001, W = 0.220073863863945, b = [[1.16]
#  [1.18]]
# step = %04d, cost = 2201, W = 0.21466350555419922, b = [[1.18]
#  [1.2 ]]
# step = %04d, cost = 2401, W = 0.2095157653093338, b = [[1.21]
#  [1.22]]
# ...

# %%
slope = w_hat[0] / w_hat[1]

xx=np.linspace(np.min(x_train[:,0]), np.max(x_train[:,0]), 100)
yy = -slope * xx - b_hat/w_hat[1]

colors = ['red' if l == 0 else 'blue' for l in y_train]
plt.xlabel("auto  transport")
plt.ylabel("public transport")
plt.scatter(x_train[:, 0], x_train[:, 1], label='Logistic Regression', color=colors)
plt.plot(xx,yy,label = 'Decision Boundary')
plt.show()

# %% [markdown]
# # **Accuracy**

# %%
import tensorflow as tf

def accuracy(hypo, label):
    predicted = tf.cast(hypo > 0.5, dtype=tf.float32)
    accuracyd = tf.reduce_mean(tf.cast(tf.equal(predicted, label), dtype=tf.float32))
    return accuracyd

acc = accuracy(hypothesis(x_train), y_train).numpy()
print("Accuracy = %s" % acc)
# Out:
# Accuracy = 1.0

# %%
import numpy as np
import tensorflow as tf

x_train = np.array([[3., 0.], [4., 1.]], dtype=np.float32)
y_train = np.array([[0.], [1.]], dtype=np.float32)

# def hypothesis(x):
#     # 가설을 정의하는 함수가 필요합니다. 예를 들어, 간단한 선형 회귀 모델로 정의할 수 있습니다.
#     W = tf.Variable(tf.random.normal([2, 1]), dtype=tf.float32)
#     b = tf.Variable(tf.random.normal([1]), dtype=tf.float32)
#     return tf.sigmoid(tf.matmul(x, W) + b)

x_train_predict = hypothesis(x_train)
print("Prob: \n", x_train_predict.numpy())
print("Result: \n", tf.cast(x_train_predict > 0.5, dtype=tf.float32).numpy())
# Out:
# Prob:
#  [[0.14]
#  [0.23]]
# Result:
#  [[0.]
#  [0.]]
